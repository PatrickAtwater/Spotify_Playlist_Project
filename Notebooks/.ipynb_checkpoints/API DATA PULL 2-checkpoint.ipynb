# %%
import pandas as pd
import requests
import spotipy.util as util
import spotipy
pd.options.display.max_rows = 1000
import datetime
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id ='b5762be2d23d43b189262e8c53a6078c'
client_secret = 'a7e8d83649314303817889927c027728'
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# username = '122552225'
# client_id ='b5762be2d23d43b189262e8c53a6078c'
# client_secret = 'a7e8d83649314303817889927c027728'
# redirect_uri = 'http://localhost:7777/callback'
# scope = 'user-read-recently-played'

# token = util.prompt_for_user_token(username=username, 
#                                    scope=scope, 
#                                    client_id=client_id,   
#                                    client_secret=client_secret,     
#                                    redirect_uri=redirect_uri)
# sp = spotipy.Spotify(auth=token)

# %%
urn = 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'
artist = sp.artist(urn)
artist

# %%
cat_track_df = pd.read_csv('songs_by_cat_2021-08-11 09.54.23.367182.csv')

# %%
songmeta_temp = {}
meta_df_4= pd.DataFrame()
cat_track_df_length = len(cat_track_df)
for i,row in cat_track_df.iloc[45000:cat_track_df_length].iterrows():
    print(i)
    try:
        song_features = sp.audio_features(row['track_id'])[0]
        sp.artist(row['artist_id'])
        artist_info = sp.artist(row['artist_id'])
        artist_followers = artist_info.get('followers').get('total')
        artist_genres = artist_info.get('genres')
        artist_popularity = artist_info.get('popularity')
        if song_features == None or artist_info == None:
            continue
        else:
            for k,v in song_features.items():
                songmeta_temp[k]=[v]
            songmeta_temp['artist_followers']=[artist_followers]
            songmeta_temp['artist_genres']=[artist_genres]
            songmeta_temp['artist_popularity']=[artist_popularity]
            song_features_temp_df = pd.DataFrame.from_dict(songmeta_temp)
            meta_df_4 = pd.concat([meta_df_4, song_features_temp_df])
    except:
        continue

# %%
now = str(datetime.datetime.now())
now
meta_df_4.to_csv(f'meta_df_6.csv')

# %%
meta_df_1 = pd.read_csv('meta_df_1_2021-08-10 13.00.16.461806.csv')
meta_df_2 = pd.read_csv('meta_df_2_2021-08-10 13.01.01.260547.csv')
meta_df_3 = pd.read_csv('meta_df_3_2021-08-12 10.32.57.983797.csv')
meta_df_4 = pd.read_csv('meta_df_4_2021-08-12 13.47.30.339870.csv')
meta_df_5 = pd.read_csv('meta_df_5.csv')
meta_df_6 = pd.read_csv('meta_df_6.csv')

# %%
meta_df = pd.DataFrame()
meta_df = pd.concat([meta_df,meta_df_1,meta_df_2,meta_df_3, meta_df_4, meta_df_5, meta_df_6])

# %%
meta_df=meta_df.drop_duplicates(subset=meta_df.columns.difference(['artist_genres']),keep='first')

# %%
meta_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
len(meta_df)

# %%
cat_track_df_length

# %%
cat_song_merged = pd.merge(cat_track_df, meta_df, how = 'left', left_on='track_id', right_on='id' )
cat_song_merged.drop(['id', 'uri', 'track_href', 'Unnamed: 0'], axis = 1, inplace=True)
cat_song_merged

# %%
cat_song_merged['is_duplicated'] = cat_song_merged.duplicated()
cat_song_merged.value_counts(subset= ['is_duplicated'])

# %%
cat_song_merged = cat_song_merged.drop_duplicates(subset=cat_song_merged.columns.difference(['artist_genres']),keep='first')

# %%
cat_song_merged.loc[cat_song_merged['is_duplicated']==True, 'track_id'].sort_values()

# %%
get_id_hh = sp.search('Hannah Holbrook', type='artist')
get_id_hh
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=Hannah+Holbrook&type=artist&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#     'followers': {'href': None, 'total': 325},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#     'id': '1GAOjRdLnEZOsHoAshVXui',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb851cb051c9507fc4b964745b',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174851cb051c9507fc4b964745b',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178851cb051c9507fc4b964745b',
#       'width': 160}],
#     'name': 'Hannah Holbrook',
#     'popularity': 7,
#     'type': 'artist',
#     'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 1}}

# %%
tracks_hh=sp.artist_top_tracks('1GAOjRdLnEZOsHoAshVXui')
tracks_hh
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#       'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#       'id': '1GAOjRdLnEZOsHoAshVXui',
#       'name': 'Hannah Holbrook',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6fLpW43YeWrsSOvCVT1buq'},
#     'href': 'https://api.spotify.com/v1/albums/6fLpW43YeWrsSOvCVT1buq',
#     'id': '6fLpW43YeWrsSOvCVT1buq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27381e98eb9afa691a534e2906c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0281e98eb9afa691a534e2906c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485181e98eb9afa691a534e2906c',
#       'width': 64}],
#     'name': 'You Should Let Me Love You',
#     'release_date': '2020-02-07',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6fLpW43YeWrsSOvCVT1buq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#      'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#      'id': '1GAOjRdLnEZOsHoAshVXui',
#      'name': 'Hannah Holbrook',
#      'type': 'artist',
#      'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#    'disc_number': 1,
#    'duration_ms': 224670,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZFYZ2068554'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3sbL6NUW8Roj6Di8I4LJxd'},
#    'href': 'https://api.spotify.com/v1/tracks/3sbL6NUW8Roj6Di8I4LJxd',
#    'id': '3sbL6NUW8Roj6Di8I4LJxd',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'You Should Let Me Love You',
#    'popularity': 15,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c0d0d3c76e9248d65107729705154c850721b1ea?cid=b5762be2d23d43b189262e8c53a6078c',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3sbL6NUW8Roj6Di8I4LJxd'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#       'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#       'id': '1GAOjRdLnEZOsHoAshVXui',
#       'name': 'Hannah Holbrook',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4vbpE9uKfZnHEKoqQiIBWD'},
#     'href': 'https://api.spotify.com/v1/albums/4vbpE9uKfZnHEKoqQiIBWD',
#     'id': '4vbpE9uKfZnHEKoqQiIBWD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735095b4daf51eb05acb70f223',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025095b4daf51eb05acb70f223',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515095b4daf51eb05acb70f223',
#       'width': 64}],
#     'name': 'Late Bloomer',
#     'release_date': '2019-01-04',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:4vbpE9uKfZnHEKoqQiIBWD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#      'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#      'id': '1GAOjRdLnEZOsHoAshVXui',
#      'name': 'Hannah Holbrook',
#      'type': 'artist',
#      'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6WHKXylkysNcktHfFN7lhE'},
#      'href': 'https://api.spotify.com/v1/artists/6WHKXylkysNcktHfFN7lhE',
#      'id': '6WHKXylkysNcktHfFN7lhE',
#      'name': 'Jonathan Yudkin',
#      'type': 'artist',
#      'uri': 'spotify:artist:6WHKXylkysNcktHfFN7lhE'}],
#    'disc_number': 1,
#    'duration_ms': 411960,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCABR1312357'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1EOABXJWQZ0gvtQjFWWbJz'},
#    'href': 'https://api.spotify.com/v1/tracks/1EOABXJWQZ0gvtQjFWWbJz',
#    'id': '1EOABXJWQZ0gvtQjFWWbJz',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'First Flight',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d092cbe6c2ad2c4d9ca450301e89e809a7f475a9?cid=b5762be2d23d43b189262e8c53a6078c',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:1EOABXJWQZ0gvtQjFWWbJz'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#       'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#       'id': '1GAOjRdLnEZOsHoAshVXui',
#       'name': 'Hannah Holbrook',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4vbpE9uKfZnHEKoqQiIBWD'},
#     'href': 'https://api.spotify.com/v1/albums/4vbpE9uKfZnHEKoqQiIBWD',
#     'id': '4vbpE9uKfZnHEKoqQiIBWD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735095b4daf51eb05acb70f223',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025095b4daf51eb05acb70f223',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515095b4daf51eb05acb70f223',
#       'width': 64}],
#     'name': 'Late Bloomer',
#     'release_date': '2019-01-04',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:4vbpE9uKfZnHEKoqQiIBWD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#      'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#      'id': '1GAOjRdLnEZOsHoAshVXui',
#      'name': 'Hannah Holbrook',
#      'type': 'artist',
#      'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#    'disc_number': 1,
#    'duration_ms': 175933,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCABR1312353'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7rsFhZzKnCdrKPNyZopXmM'},
#    'href': 'https://api.spotify.com/v1/tracks/7rsFhZzKnCdrKPNyZopXmM',
#    'id': '7rsFhZzKnCdrKPNyZopXmM',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Eloise',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/61c133c50dfdceaa5dcce79ed09b6be910b0b563?cid=b5762be2d23d43b189262e8c53a6078c',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7rsFhZzKnCdrKPNyZopXmM'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#       'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#       'id': '1GAOjRdLnEZOsHoAshVXui',
#       'name': 'Hannah Holbrook',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4vbpE9uKfZnHEKoqQiIBWD'},
#     'href': 'https://api.spotify.com/v1/albums/4vbpE9uKfZnHEKoqQiIBWD',
#     'id': '4vbpE9uKfZnHEKoqQiIBWD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735095b4daf51eb05acb70f223',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025095b4daf51eb05acb70f223',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515095b4daf51eb05acb70f223',
#       'width': 64}],
#     'name': 'Late Bloomer',
#     'release_date': '2019-01-04',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:4vbpE9uKfZnHEKoqQiIBWD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#      'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#      'id': '1GAOjRdLnEZOsHoAshVXui',
#      'name': 'Hannah Holbrook',
#      'type': 'artist',
#      'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#    'disc_number': 1,
#    'duration_ms': 139266,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCABR1312351'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7lp0gZQDZqx1LXPajG0A3R'},
#    'href': 'https://api.spotify.com/v1/tracks/7lp0gZQDZqx1LXPajG0A3R',
#    'id': '7lp0gZQDZqx1LXPajG0A3R',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Late Bloomer',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b722e06261d644ce60af5df424d4e701757fdc9b?cid=b5762be2d23d43b189262e8c53a6078c',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7lp0gZQDZqx1LXPajG0A3R'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#       'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#       'id': '1GAOjRdLnEZOsHoAshVXui',
#       'name': 'Hannah Holbrook',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4vbpE9uKfZnHEKoqQiIBWD'},
#     'href': 'https://api.spotify.com/v1/albums/4vbpE9uKfZnHEKoqQiIBWD',
#     'id': '4vbpE9uKfZnHEKoqQiIBWD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735095b4daf51eb05acb70f223',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025095b4daf51eb05acb70f223',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515095b4daf51eb05acb70f223',
#       'width': 64}],
#     'name': 'Late Bloomer',
#     'release_date': '2019-01-04',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:4vbpE9uKfZnHEKoqQiIBWD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#      'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#      'id': '1GAOjRdLnEZOsHoAshVXui',
#      'name': 'Hannah Holbrook',
#      'type': 'artist',
#      'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#    'disc_number': 1,
#    'duration_ms': 130186,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCABR1312355'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3CQQbwfjykdgLjRBQGBC8u'},
#    'href': 'https://api.spotify.com/v1/tracks/3CQQbwfjykdgLjRBQGBC8u',
#    'id': '3CQQbwfjykdgLjRBQGBC8u',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Tango On A Tightrope',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8b54027d1a7ea8d122c288f59bde93992fcb8ee0?cid=b5762be2d23d43b189262e8c53a6078c',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:3CQQbwfjykdgLjRBQGBC8u'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#       'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#       'id': '1GAOjRdLnEZOsHoAshVXui',
#       'name': 'Hannah Holbrook',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4vbpE9uKfZnHEKoqQiIBWD'},
#     'href': 'https://api.spotify.com/v1/albums/4vbpE9uKfZnHEKoqQiIBWD',
#     'id': '4vbpE9uKfZnHEKoqQiIBWD',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735095b4daf51eb05acb70f223',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025095b4daf51eb05acb70f223',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515095b4daf51eb05acb70f223',
#       'width': 64}],
#     'name': 'Late Bloomer',
#     'release_date': '2019-01-04',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:4vbpE9uKfZnHEKoqQiIBWD'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#      'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#      'id': '1GAOjRdLnEZOsHoAshVXui',
#      'name': 'Hannah Holbrook',
#      'type': 'artist',
#      'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#    'disc_number': 1,
#    'duration_ms': 125610,
#    'explicit': False,
#    'external_ids': {'isrc': 'TCABR1312354'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3jmErvzFCijtOLqZfNoxZh'},
#    'href': 'https://api.spotify.com/v1/tracks/3jmErvzFCijtOLqZfNoxZh',
#    'id': '3jmErvzFCijtOLqZfNoxZh',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Transylvanian Chase',
#    'popularity': 1,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ad39affd63f89c24576d602f193eaf7f87b28bfd?cid=b5762be2d23d43b189262e8c53a6078c',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3jmErvzFCijtOLqZfNoxZh'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#       'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#       'id': '1GAOjRdLnEZOsHoAshVXui',
#       'name': 'Hannah Holbrook',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6Aepv2iLm6huO5qJMx2CTg'},
#     'href': 'https://api.spotify.com/v1/albums/6Aepv2iLm6huO5qJMx2CTg',
#     'id': '6Aepv2iLm6huO5qJMx2CTg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bc77011efd734a6e3d75c447',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bc77011efd734a6e3d75c447',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bc77011efd734a6e3d75c447',
#       'width': 64}],
#     'name': 'You Should Let Me Love You (With Strings)',
#     'release_date': '2020-11-20',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6Aepv2iLm6huO5qJMx2CTg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#      'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#      'id': '1GAOjRdLnEZOsHoAshVXui',
#      'name': 'Hannah Holbrook',
#      'type': 'artist',
#      'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#    'disc_number': 1,
#    'duration_ms': 253972,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZMEQ2024008'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4wOZwPTZyBDubQOboTnekk'},
#    'href': 'https://api.spotify.com/v1/tracks/4wOZwPTZyBDubQOboTnekk',
#    'id': '4wOZwPTZyBDubQOboTnekk',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'You Should Let Me Love You (With Strings)',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0d7e7c5b232c3715e9202f0511aeb7e53568094b?cid=b5762be2d23d43b189262e8c53a6078c',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4wOZwPTZyBDubQOboTnekk'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#       'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#       'id': '1GAOjRdLnEZOsHoAshVXui',
#       'name': 'Hannah Holbrook',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2LBFHnfc28IeQhVGYG2eZk'},
#     'href': 'https://api.spotify.com/v1/albums/2LBFHnfc28IeQhVGYG2eZk',
#     'id': '2LBFHnfc28IeQhVGYG2eZk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b786aa730f2fb6de0865185e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b786aa730f2fb6de0865185e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b786aa730f2fb6de0865185e',
#       'width': 64}],
#     'name': 'Doxology',
#     'release_date': '2020-04-10',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2LBFHnfc28IeQhVGYG2eZk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#      'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#      'id': '1GAOjRdLnEZOsHoAshVXui',
#      'name': 'Hannah Holbrook',
#      'type': 'artist',
#      'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#    'disc_number': 1,
#    'duration_ms': 173609,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZDA52045035'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0LHpUav15QwVhEPQvEznIb'},
#    'href': 'https://api.spotify.com/v1/tracks/0LHpUav15QwVhEPQvEznIb',
#    'id': '0LHpUav15QwVhEPQvEznIb',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Doxology',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/19ea3a4bd790a4323f26a4b9e8ba6129c1142c8c?cid=b5762be2d23d43b189262e8c53a6078c',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0LHpUav15QwVhEPQvEznIb'},
#   {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#       'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#       'id': '1GAOjRdLnEZOsHoAshVXui',
#       'name': 'Hannah Holbrook',
#       'type': 'artist',
#       'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4zUKOWZANeHyIP8G4k6lA2'},
#     'href': 'https://api.spotify.com/v1/albums/4zUKOWZANeHyIP8G4k6lA2',
#     'id': '4zUKOWZANeHyIP8G4k6lA2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273339c06c21684636d17628dde',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02339c06c21684636d17628dde',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851339c06c21684636d17628dde',
#       'width': 64}],
#     'name': 'Christmas With You',
#     'release_date': '2020-11-29',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4zUKOWZANeHyIP8G4k6lA2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1GAOjRdLnEZOsHoAshVXui'},
#      'href': 'https://api.spotify.com/v1/artists/1GAOjRdLnEZOsHoAshVXui',
#      'id': '1GAOjRdLnEZOsHoAshVXui',
#      'name': 'Hannah Holbrook',
#      'type': 'artist',
#      'uri': 'spotify:artist:1GAOjRdLnEZOsHoAshVXui'}],
#    'disc_number': 1,
#    'duration_ms': 218354,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZNWV2042921'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1bfhge6CfxlQdInirMqUVx'},
#    'href': 'https://api.spotify.com/v1/tracks/1bfhge6CfxlQdInirMqUVx',
#    'id': '1bfhge6CfxlQdInirMqUVx',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Christmas With You',
#    'popularity': 0,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a1a694b10d748526df35d2ed43ed546bde15a68e?cid=b5762be2d23d43b189262e8c53a6078c',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1bfhge6CfxlQdInirMqUVx'}]}

# %%
number_of_tracks = len(tracks_hh.get('tracks'))
artist_df = pd.DataFrame()
for x in range(0,number_of_tracks):
    track_title = tracks_hh.get('tracks')[x].get('name')
    track_id = tracks_hh.get('tracks')[x].get('id')
    track_artist = tracks_hh.get('tracks')[1].get('artists')[0].get('name')
    artist_id= tracks_hh.get('tracks')[x].get('artists')[0].get('id')
    track_album = tracks_hh.get('tracks')[x].get('album').get('name')
    album_id= tracks_hh.get('tracks')[x].get('album').get('id')
    track_release_date = tracks_hh.get('tracks')[x].get('album').get('release_date')
    album_type =  tracks_hh.get('tracks')[x].get('album').get('album_type')
    track_popularity = tracks_hh.get('tracks')[x].get('popularity')
    columns = {'track_title':[track_title],
                'track_id':[track_id],
                'track_artist':[track_artist],
                'artist_id':[artist_id],
                'track_album':[track_album],
                'track_release_date':[track_release_date],
                'genre_album_type':[album_type],
                'genre_track_popularity':[track_popularity]

                      }
    temp_df=pd.DataFrame.from_dict(columns)
    artist_df= pd.concat([artist_df, temp_df])
artist_df
# Out:
#                                  track_title                track_id  \
# 0                 You Should Let Me Love You  3sbL6NUW8Roj6Di8I4LJxd
# 0                               First Flight  1EOABXJWQZ0gvtQjFWWbJz
# 0                                     Eloise  7rsFhZzKnCdrKPNyZopXmM
# 0                               Late Bloomer  7lp0gZQDZqx1LXPajG0A3R
# 0                       Tango On A Tightrope  3CQQbwfjykdgLjRBQGBC8u
# 0                        Transylvanian Chase  3jmErvzFCijtOLqZfNoxZh
# 0  You Should Let Me Love You (With Strings)  4wOZwPTZyBDubQOboTnekk
# 0                                   Doxology  0LHpUav15QwVhEPQvEznIb
# 0                         Christmas With You  1bfhge6CfxlQdInirMqUVx
#
#       track_artist               artist_id  \
# 0  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 0  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 0  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 0  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 0  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 0  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 0  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 0  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 0  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
#
#                                  track_album track_release_date  \
# 0                 You Should Let Me Love You         2020-02-07
# 0                               Late Bloomer         2019-01-04
# 0                               Late Bloomer         2019-01-04
# 0                               Late Bloomer         2019-01-04
# 0                               Late Bloomer         2019-01-04
# 0                               Late Bloomer         2019-01-04
# 0  You Should Let Me Love You (With Strings)         2020-11-20
# 0                                   Doxology         2020-04-10
# 0                         Christmas With You         2020-11-29
#
#   genre_album_type  genre_track_popularity
# 0           single                      15
# 0           single                       2
# 0           single                       2
# 0           single                       1
# 0           single                       1
# 0           single                       1
# 0           single                       0
# 0           single                       0
# 0           single                       0

# %%
songmeta_temp = {}
meta_df= pd.DataFrame()
for i,row in artist_df.iterrows():
    print(i)
    try:
        song_features = sp.audio_features(row['track_id'])[0]
        artist_info = sp.artist(row['artist_id'])
        artist_followers = artist_info.get('followers').get('total')
        artist_genres = artist_info.get('genres')
        artist_popularity = artist_info.get('popularity')
        if song_features == None or artist_info == None:
            continue
        else:
            for k,v in song_features.items():
                songmeta_temp[k]=[v]
            songmeta_temp['artist_followers']=[artist_followers]
            songmeta_temp['artist_genres']=[artist_genres]
            songmeta_temp['artist_popularity']=[artist_popularity]
            song_features_temp_df = pd.DataFrame.from_dict(songmeta_temp)
            meta_df = pd.concat([meta_df, song_features_temp_df])
    except:
        continue
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
meta_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.320  0.1450   10   -13.275     1       0.0476         0.983
# 0         0.232  0.1430    4   -20.488     0       0.0412         0.983
# 0         0.458  0.0330    2   -28.548     1       0.0512         0.984
# 0         0.197  0.1140    7   -24.782     1       0.0411         0.982
# 0         0.293  0.1560    9   -25.532     0       0.0410         0.973
# 0         0.322  0.1630    0   -23.814     1       0.0437         0.918
# 0         0.202  0.0956   10   -13.959     1       0.0346         0.877
# 0         0.433  0.1940    4   -19.714     1       0.0493         0.974
# 0         0.391  0.0779    0   -17.738     1       0.0374         0.852
#
#    instrumentalness  liveness  valence  ...            type  \
# 0          0.000027    0.1150   0.2010  ...  audio_features
# 0          0.681000    0.1330   0.0584  ...  audio_features
# 0          0.943000    0.0659   0.1630  ...  audio_features
# 0          0.939000    0.1330   0.2040  ...  audio_features
# 0          0.878000    0.1360   0.4670  ...  audio_features
# 0          0.903000    0.1130   0.1610  ...  audio_features
# 0          0.000003    0.0973   0.1720  ...  audio_features
# 0          0.849000    0.1030   0.2330  ...  audio_features
# 0          0.000009    0.3570   0.2630  ...  audio_features
#
#                        id                                   uri  \
# 0  3sbL6NUW8Roj6Di8I4LJxd  spotify:track:3sbL6NUW8Roj6Di8I4LJxd
# 0  1EOABXJWQZ0gvtQjFWWbJz  spotify:track:1EOABXJWQZ0gvtQjFWWbJz
# 0  7rsFhZzKnCdrKPNyZopXmM  spotify:track:7rsFhZzKnCdrKPNyZopXmM
# 0  7lp0gZQDZqx1LXPajG0A3R  spotify:track:7lp0gZQDZqx1LXPajG0A3R
# 0  3CQQbwfjykdgLjRBQGBC8u  spotify:track:3CQQbwfjykdgLjRBQGBC8u
# 0  3jmErvzFCijtOLqZfNoxZh  spotify:track:3jmErvzFCijtOLqZfNoxZh
# 0  4wOZwPTZyBDubQOboTnekk  spotify:track:4wOZwPTZyBDubQOboTnekk
# 0  0LHpUav15QwVhEPQvEznIb  spotify:track:0LHpUav15QwVhEPQvEznIb
# 0  1bfhge6CfxlQdInirMqUVx  spotify:track:1bfhge6CfxlQdInirMqUVx
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3sbL6NUW8Roj...
# 0  https://api.spotify.com/v1/tracks/1EOABXJWQZ0g...
# 0  https://api.spotify.com/v1/tracks/7rsFhZzKnCdr...
# 0  https://api.spotify.com/v1/tracks/7lp0gZQDZqx1...
# 0  https://api.spotify.com/v1/tracks/3CQQbwfjykdg...
# 0  https://api.spotify.com/v1/tracks/3jmErvzFCijt...
# 0  https://api.spotify.com/v1/tracks/4wOZwPTZyBDu...
# 0  https://api.spotify.com/v1/tracks/0LHpUav15QwV...
# 0  https://api.spotify.com/v1/tracks/1bfhge6CfxlQ...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3sbL...      224670
# 0  https://api.spotify.com/v1/audio-analysis/1EOA...      411960
# 0  https://api.spotify.com/v1/audio-analysis/7rsF...      175933
# 0  https://api.spotify.com/v1/audio-analysis/7lp0...      139267
# 0  https://api.spotify.com/v1/audio-analysis/3CQQ...      130187
# 0  https://api.spotify.com/v1/audio-analysis/3jmE...      125610
# 0  https://api.spotify.com/v1/audio-analysis/4wOZ...      253973
# 0  https://api.spotify.com/v1/audio-analysis/0LHp...      173610
# 0  https://api.spotify.com/v1/audio-analysis/1bfh...      218355
#
#    time_signature  artist_followers  artist_genres artist_popularity
# 0               4               325             []                 7
# 0               4               325             []                 7
# 0               4               325             []                 7
# 0               4               325             []                 7
# 0               3               325             []                 7
# 0               4               325             []                 7
# 0               3               325             []                 7
# 0               4               325             []                 7
# 0               4               325             []                 7
#
# [9 rows x 21 columns]

# %%
artist_merged = pd.merge(artist_df, meta_df, how = 'left', left_on='track_id', right_on='id' )
artist_merged.drop(['id', 'uri', 'track_href'], axis = 1, inplace=True)
artist_merged
# Out:
#                                  track_title                track_id  \
# 0                 You Should Let Me Love You  3sbL6NUW8Roj6Di8I4LJxd
# 1                               First Flight  1EOABXJWQZ0gvtQjFWWbJz
# 2                                     Eloise  7rsFhZzKnCdrKPNyZopXmM
# 3                               Late Bloomer  7lp0gZQDZqx1LXPajG0A3R
# 4                       Tango On A Tightrope  3CQQbwfjykdgLjRBQGBC8u
# 5                        Transylvanian Chase  3jmErvzFCijtOLqZfNoxZh
# 6  You Should Let Me Love You (With Strings)  4wOZwPTZyBDubQOboTnekk
# 7                                   Doxology  0LHpUav15QwVhEPQvEznIb
# 8                         Christmas With You  1bfhge6CfxlQdInirMqUVx
#
#       track_artist               artist_id  \
# 0  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 1  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 2  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 3  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 4  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 5  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 6  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 7  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
# 8  Hannah Holbrook  1GAOjRdLnEZOsHoAshVXui
#
#                                  track_album track_release_date  \
# 0                 You Should Let Me Love You         2020-02-07
# 1                               Late Bloomer         2019-01-04
# 2                               Late Bloomer         2019-01-04
# 3                               Late Bloomer         2019-01-04
# 4                               Late Bloomer         2019-01-04
# 5                               Late Bloomer         2019-01-04
# 6  You Should Let Me Love You (With Strings)         2020-11-20
# 7                                   Doxology         2020-04-10
# 8                         Christmas With You         2020-11-29
#
#   genre_album_type  genre_track_popularity  danceability  energy  ...  \
# 0           single                      15         0.320  0.1450  ...
# 1           single                       2         0.232  0.1430  ...
# 2           single                       2         0.458  0.0330  ...
# 3           single                       1         0.197  0.1140  ...
# 4           single                       1         0.293  0.1560  ...
# 5           single                       1         0.322  0.1630  ...
# 6           single                       0         0.202  0.0956  ...
# 7           single                       0         0.433  0.1940  ...
# 8           single                       0         0.391  0.0779  ...
#
#    liveness  valence    tempo            type  \
# 0    0.1150   0.2010   80.229  audio_features
# 1    0.1330   0.0584   81.144  audio_features
# 2    0.0659   0.1630   68.962  audio_features
# 3    0.1330   0.2040  173.450  audio_features
# 4    0.1360   0.4670  107.592  audio_features
# 5    0.1130   0.1610   78.261  audio_features
# 6    0.0973   0.1720   76.589  audio_features
# 7    0.1030   0.2330   93.424  audio_features
# 8    0.3570   0.2630   94.747  audio_features
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3sbL...       224670
# 1  https://api.spotify.com/v1/audio-analysis/1EOA...       411960
# 2  https://api.spotify.com/v1/audio-analysis/7rsF...       175933
# 3  https://api.spotify.com/v1/audio-analysis/7lp0...       139267
# 4  https://api.spotify.com/v1/audio-analysis/3CQQ...       130187
# 5  https://api.spotify.com/v1/audio-analysis/3jmE...       125610
# 6  https://api.spotify.com/v1/audio-analysis/4wOZ...       253973
# 7  https://api.spotify.com/v1/audio-analysis/0LHp...       173610
# 8  https://api.spotify.com/v1/audio-analysis/1bfh...       218355
#
#    time_signature  artist_followers  artist_genres artist_popularity
# 0               4               325             []                 7
# 1               4               325             []                 7
# 2               4               325             []                 7
# 3               4               325             []                 7
# 4               3               325             []                 7
# 5               4               325             []                 7
# 6               3               325             []                 7
# 7               4               325             []                 7
# 8               4               325             []                 7
#
# [9 rows x 26 columns]

# %%
artist_merged.to_csv('HH_track_data.csv')

# %%
YSLMLY_audio= sp.audio_features('3sbL6NUW8Roj6Di8I4LJxd')
YSLMLY_audio
# Out:
# [{'danceability': 0.32,
#   'energy': 0.145,
#   'key': 10,
#   'loudness': -13.275,
#   'mode': 1,
#   'speechiness': 0.0476,
#   'acousticness': 0.983,
#   'instrumentalness': 2.73e-05,
#   'liveness': 0.115,
#   'valence': 0.201,
#   'tempo': 80.229,
#   'type': 'audio_features',
#   'id': '3sbL6NUW8Roj6Di8I4LJxd',
#   'uri': 'spotify:track:3sbL6NUW8Roj6Di8I4LJxd',
#   'track_href': 'https://api.spotify.com/v1/tracks/3sbL6NUW8Roj6Di8I4LJxd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3sbL6NUW8Roj6Di8I4LJxd',
#   'duration_ms': 224670,
#   'time_signature': 4}]
