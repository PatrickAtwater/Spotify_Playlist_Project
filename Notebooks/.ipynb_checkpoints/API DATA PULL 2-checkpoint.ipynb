# %%
import pandas as pd
import requests
import spotipy.util as util
import spotipy
pd.options.display.max_rows = 1000
import datetime
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_id ='b5762be2d23d43b189262e8c53a6078c'
client_secret = 'a7e8d83649314303817889927c027728'
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
# username = '122552225'
# client_id ='b5762be2d23d43b189262e8c53a6078c'
# client_secret = 'a7e8d83649314303817889927c027728'
# redirect_uri = 'http://localhost:7777/callback'
# scope = 'user-read-recently-played'

# token = util.prompt_for_user_token(username=username, 
#                                    scope=scope, 
#                                    client_id=client_id,   
#                                    client_secret=client_secret,     
#                                    redirect_uri=redirect_uri)
# sp = spotipy.Spotify(auth=token)

# %%
urn = 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'
artist = sp.artist(urn)
artist

# %%
cat_track_df = pd.read_csv('songs_by_cat_2021-08-11 09.54.23.367182.csv')

# %%
songmeta_temp = {}
meta_df_4= pd.DataFrame()
cat_track_df_length = len(cat_track_df)
for i,row in cat_track_df.iloc[45000:cat_track_df_length].iterrows():
    print(i)
    try:
        song_features = sp.audio_features(row['track_id'])[0]
        sp.artist(row['artist_id'])
        artist_info = sp.artist(row['artist_id'])
        artist_followers = artist_info.get('followers').get('total')
        artist_genres = artist_info.get('genres')
        artist_popularity = artist_info.get('popularity')
        if song_features == None or artist_info == None:
            continue
        else:
            for k,v in song_features.items():
                songmeta_temp[k]=[v]
            songmeta_temp['artist_followers']=[artist_followers]
            songmeta_temp['artist_genres']=[artist_genres]
            songmeta_temp['artist_popularity']=[artist_popularity]
            song_features_temp_df = pd.DataFrame.from_dict(songmeta_temp)
            meta_df_4 = pd.concat([meta_df_4, song_features_temp_df])
    except:
        continue

# %%
now = str(datetime.datetime.now())
now
meta_df_4.to_csv(f'meta_df_6.csv')

# %%
meta_df_1 = pd.read_csv('meta_df_1_2021-08-10 13.00.16.461806.csv')
meta_df_2 = pd.read_csv('meta_df_2_2021-08-10 13.01.01.260547.csv')
meta_df_3 = pd.read_csv('meta_df_3_2021-08-12 10.32.57.983797.csv')
meta_df_4 = pd.read_csv('meta_df_4_2021-08-12 13.47.30.339870.csv')
meta_df_5 = pd.read_csv('meta_df_5.csv')
meta_df_6 = pd.read_csv('meta_df_6.csv')

# %%
meta_df = pd.DataFrame()
meta_df = pd.concat([meta_df,meta_df_1,meta_df_2,meta_df_3, meta_df_4, meta_df_5, meta_df_6])

# %%
meta_df=meta_df.drop_duplicates(subset=meta_df.columns.difference(['artist_genres']),keep='first')

# %%
meta_df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
len(meta_df)

# %%
cat_track_df_length

# %%
cat_song_merged = pd.merge(cat_track_df, meta_df, how = 'left', left_on='track_id', right_on='id' )
cat_song_merged.drop(['id', 'uri', 'track_href', 'Unnamed: 0'], axis = 1, inplace=True)
cat_song_merged

# %%
cat_song_merged['is_duplicated'] = cat_song_merged.duplicated()
cat_song_merged.value_counts(subset= ['is_duplicated'])

# %%
cat_song_merged = cat_song_merged.drop_duplicates(subset=cat_song_merged.columns.difference(['artist_genres']),keep='first')

# %%
cat_song_merged.loc[cat_song_merged['is_duplicated']==True, 'track_id'].sort_values()

# %%
get_id_hh = sp.search('Hannah Holbrook', type='artist').get('artists').get('items')[0].get('id')
get_id_hh

# %%
tracks_hh=sp.artist_top_tracks('1GAOjRdLnEZOsHoAshVXui')
tracks_hh

# %%
number_of_tracks = len(tracks_hh.get('tracks'))
artist_df = pd.DataFrame()
for x in range(0,number_of_tracks):
    track_title = tracks_hh.get('tracks')[x].get('name')
    track_id = tracks_hh.get('tracks')[x].get('id')
    track_artist = tracks_hh.get('tracks')[1].get('artists')[0].get('name')
    artist_id= tracks_hh.get('tracks')[x].get('artists')[0].get('id')
    track_album = tracks_hh.get('tracks')[x].get('album').get('name')
    album_id= tracks_hh.get('tracks')[x].get('album').get('id')
    track_release_date = tracks_hh.get('tracks')[x].get('album').get('release_date')
    album_type =  tracks_hh.get('tracks')[x].get('album').get('album_type')
    track_popularity = tracks_hh.get('tracks')[x].get('popularity')
    columns = {'track_title':[track_title],
                'track_id':[track_id],
                'track_artist':[track_artist],
                'artist_id':[artist_id],
                'track_album':[track_album],
                'track_release_date':[track_release_date],
                'genre_album_type':[album_type],
                'genre_track_popularity':[track_popularity]

                      }
    temp_df=pd.DataFrame.from_dict(columns)
    artist_df= pd.concat([artist_df, temp_df])
artist_df

# %%
songmeta_temp = {}
meta_df= pd.DataFrame()
for i,row in artist_df.iterrows():
    print(i)
    try:
        song_features = sp.audio_features(row['track_id'])[0]
        artist_info = sp.artist(row['artist_id'])
        artist_followers = artist_info.get('followers').get('total')
        artist_genres = artist_info.get('genres')
        artist_popularity = artist_info.get('popularity')
        if song_features == None or artist_info == None:
            continue
        else:
            for k,v in song_features.items():
                songmeta_temp[k]=[v]
            songmeta_temp['artist_followers']=[artist_followers]
            songmeta_temp['artist_genres']=[artist_genres]
            songmeta_temp['artist_popularity']=[artist_popularity]
            song_features_temp_df = pd.DataFrame.from_dict(songmeta_temp)
            meta_df = pd.concat([meta_df, song_features_temp_df])
    except:
        continue

# %%
meta_df

# %%
artist_merged = pd.merge(artist_df, meta_df, how = 'left', left_on='track_id', right_on='id' )
artist_merged.drop(['id', 'uri', 'track_href'], axis = 1, inplace=True)
artist_merged

# %%
artist_merged.to_csv('HH_track_data.csv')

# %%
YSLMLY_audio= sp.audio_features('3sbL6NUW8Roj6Di8I4LJxd')
YSLMLY_audio

# %%
#SINGLE CALL FOR ARTIST DATAFRAME
#Import needed libraries
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Authenticate with Spotify API
client_id ='b5762be2d23d43b189262e8c53a6078c'
client_secret = 'a7e8d83649314303817889927c027728'
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)
def ArtistDataFrame(artist_name):
    #Get a given Artist's Spotify ID
    get_id_hh = sp.search(artist_name, type='artist').get('artists').get('items')[0].get('id')
    get_id_hh

    #Pull top tracks for artist
    tracks_hh=sp.artist_top_tracks(get_id_hh)
    tracks_hh

    #Create DataFrame with top tracks for artist
    number_of_tracks = len(tracks_hh.get('tracks'))
    artist_df = pd.DataFrame()
    for x in range(0,number_of_tracks):
        track_title = tracks_hh.get('tracks')[x].get('name')
        track_id = tracks_hh.get('tracks')[x].get('id')
        track_artist = tracks_hh.get('tracks')[1].get('artists')[0].get('name')
        artist_id= tracks_hh.get('tracks')[x].get('artists')[0].get('id')
        track_album = tracks_hh.get('tracks')[x].get('album').get('name')
        album_id= tracks_hh.get('tracks')[x].get('album').get('id')
        track_release_date = tracks_hh.get('tracks')[x].get('album').get('release_date')
        album_type =  tracks_hh.get('tracks')[x].get('album').get('album_type')
        track_popularity = tracks_hh.get('tracks')[x].get('popularity')
        columns = {'track_title':[track_title],
                    'track_id':[track_id],
                    'track_artist':[track_artist],
                    'artist_id':[artist_id],
                    'track_album':[track_album],
                    'track_release_date':[track_release_date],
                    'album_type':[album_type],
                    'track_popularity':[track_popularity]

                          }
        temp_df=pd.DataFrame.from_dict(columns)
        artist_df= pd.concat([artist_df, temp_df])
    artist_df

    #Pull Metadata for Artist top tracks
    songmeta_temp = {}
    meta_df= pd.DataFrame()
    for i,row in artist_df.iterrows():
        #print(i)
        try:
            song_features = sp.audio_features(row['track_id'])[0]
            artist_info = sp.artist(row['artist_id'])
            artist_followers = artist_info.get('followers').get('total')
            artist_genres = artist_info.get('genres')
            artist_popularity = artist_info.get('popularity')
            if song_features == None or artist_info == None:
                continue
            else:
                for k,v in song_features.items():
                    songmeta_temp[k]=[v]
                songmeta_temp['artist_followers']=[artist_followers]
                songmeta_temp['artist_genres']=[artist_genres]
                songmeta_temp['artist_popularity']=[artist_popularity]
                song_features_temp_df = pd.DataFrame.from_dict(songmeta_temp)
                meta_df = pd.concat([meta_df, song_features_temp_df])
        except:
            continue

    #Join MetaData to Artist Dataframe
    artist_merged = pd.merge(artist_df, meta_df, how = 'left', left_on='track_id', right_on='id' )
    artist_merged.drop(['id', 'uri', 'track_href'], axis = 1, inplace=True)
    return artist_merged

# %%
ArtistDataFrame("")
# Out:
#                                          track_title                track_id  \
# 0                     Grapevine Drums - Original Mix  0sHUvh1phkzVDUWOJ31cfJ
# 1                                               GLX3  3GuJeqxGMJr24ULHYGXhOv
# 2                                      Bright Future  0yolV3aAKF90caa44z2zt5
# 3                               AstroPilot - Sansara  5iZKz1LzuS5NOYlEuFnP8g
# 4                                        Check Point  4KCMU0qlo9wqrZIwxeRiZg
# 5                       First Contact - Original Mix  3L0yOuXmiANcx7EUhkMlya
# 6                                          Mayan Mar  5lVw4pMVG4iAd5X9197GlN
# 7                          Lake Pulse - Original Mix  510KXnerjXCg9waDR2RzUP
# 8                               Space - HuuHaa remix  6mDDiHQqbWVweCvjDpLqNb
# 9  Gravity Equals Love (feat. Michael Ukura) - Hu...  32O6syEMTrgkC9n45MQ3sq
#
#   track_artist               artist_id                    track_album  \
# 0       HuuHaa  3ar1msr3dFfOYxRxtZJDOB          Ethneomystica, Vol. 4
# 1       HuuHaa  3ar1msr3dFfOYxRxtZJDOB        Down Under The Triangle
# 2       HuuHaa  3ar1msr3dFfOYxRxtZJDOB          Spacechillers, Vol. 3
# 3       HuuHaa  3ar1msr3dFfOYxRxtZJDOB  The Biohacker's Guide To Life
# 4       HuuHaa  3ar1msr3dFfOYxRxtZJDOB  The Biohacker's Guide To Life
# 5       HuuHaa  3ar1msr3dFfOYxRxtZJDOB                      Starizona
# 6       HuuHaa  3ar1msr3dFfOYxRxtZJDOB     HaaHuu 2012 (2012 edition)
# 7       HuuHaa  3ar1msr3dFfOYxRxtZJDOB                      Starizona
# 8       HuuHaa  7HhBdMwU7EMVstq9KNxT93                   Space Art EP
# 9       HuuHaa  3ar1msr3dFfOYxRxtZJDOB    Gravity Equals Love Remixer
#
#   track_release_date   album_type  track_popularity  danceability  energy  \
# 0         2016-03-09  compilation                 4        0.6500   0.588
# 1         2013-08-20       single                 1        0.3320   0.950
# 2         2019-11-28        album                 0        0.0649   0.176
# 3         2016-11-11        album                 0        0.6620   0.801
# 4         2016-11-11        album                 0        0.6920   0.890
# 5         2016-07-01        album                 0        0.6850   0.643
# 6         2012-12-01       single                 0        0.5250   0.845
# 7         2016-07-01        album                 0        0.6900   0.593
# 8         2017-11-10       single                 0        0.6520   0.611
# 9               2013       single                 0        0.7140   0.523
#
#    ...  liveness  valence    tempo            type  \
# 0  ...    0.2870   0.0940  100.009  audio_features
# 1  ...    0.1000   0.4240  169.994  audio_features
# 2  ...    0.1060   0.0388   70.304  audio_features
# 3  ...    0.1150   0.0384   99.984  audio_features
# 4  ...    0.6770   0.4520  125.005  audio_features
# 5  ...    0.1370   0.1600  159.940  audio_features
# 6  ...    0.3880   0.5090  159.999  audio_features
# 7  ...    0.1720   0.4140  160.054  audio_features
# 8  ...    0.1300   0.1040  160.013  audio_features
# 9  ...    0.0965   0.2310  130.022  audio_features
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0sHU...       548627
# 1  https://api.spotify.com/v1/audio-analysis/3GuJ...       404335
# 2  https://api.spotify.com/v1/audio-analysis/0yol...       293680
# 3  https://api.spotify.com/v1/audio-analysis/5iZK...       451212
# 4  https://api.spotify.com/v1/audio-analysis/4KCM...       476165
# 5  https://api.spotify.com/v1/audio-analysis/3L0y...       430500
# 6  https://api.spotify.com/v1/audio-analysis/5lVw...       381224
# 7  https://api.spotify.com/v1/audio-analysis/510K...       450000
# 8  https://api.spotify.com/v1/audio-analysis/6mDD...       415000
# 9  https://api.spotify.com/v1/audio-analysis/32O6...       483000
#
#    time_signature  artist_followers  artist_genres artist_popularity
# 0               4               141             []                 1
# 1               4               141             []                 1
# 2               3               141             []                 1
# 3               4               141             []                 1
# 4               4               141             []                 1
# 5               4               141             []                 1
# 6               4               141             []                 1
# 7               4               141             []                 1
# 8               4               571  [suomisaundi]                 8
# 9               4               141             []                 1
#
# [10 rows x 26 columns]
